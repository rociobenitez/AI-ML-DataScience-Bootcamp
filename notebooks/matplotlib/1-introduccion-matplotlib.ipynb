# %% [markdown]
# # Introducción a Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Crear un gráfico simple, sin punto y coma
plt.plot()
# Out:
# []

# %%
# Crear un gráfico simple, con punto y coma
plt.plot();

# %%
# Podemos usar show() si queremos
plt.plot()
plt.show()

# %%
# Añadimos algunos datos
plt.plot([1, 2, 3, 4])

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)

# %% [markdown]
# 🔗 [Pyplot tutorial](https://matplotlib.org/stable/tutorials/pyplot.html#sphx-glr-tutorials-pyplot-py)

# %% [markdown]
# ## Crear gráficos

# %%
# Primer método (confuso)
fig = plt.figure() # crea una figura
ax = fig.add_subplot() # añade axes
plt.show()

# %%
# Segundo método (confuso)
fig = plt.figure() # crea una figura
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # añade axes
plt.show()

# %%
# Tercer método (recomendado) (más fácil y robusto)
fig, ax = plt.subplots() 
ax.plot(x, y) # añade axes

# %%
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]) # añade datos

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Anatomía de una figura en Matplotlib
#
# <img src="../../assets/section-6/matplotlib-anatomy-of-a-plot.png" width=700>

# %% [markdown]
# ## Ejemplo de flujo de trabajo en Matplotlib

# %%
# 0. Importar matplotlib
import matplotlib.pyplot as plt

# 1. Preparar los datos
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x, y)

# 4. Personalizar el gráfico
ax.set(title="Gráfico simple",
       xlabel="x-axis",
       ylabel="y-axis")

# 5. Guardar y mostrar
fig.savefig("../../assets/section-6/sample-plot.png")

# %% [markdown]
# ## Tipos de gráficos más comunes utilizando NumPy arrays
#
# - Para saber qué tipo de gráfico utilizar debemos familiarizarnos con los datos y luego ver cuál se adapta mejor a ellos.
# - Las visualizaciones de Matplotlib se construyen a partir de arrays de NumPy.
#
# * `Line plot` (gráfico de línea)
# * `Scatter plot` (diagrama de dispersión)
# * `Bar plot` (gráfico de barras)
# * `Histogram` (histograma)
# * `Subplot` (múltiples gráficos dentro de una misma figura)

# %% [markdown]
# ### Line (Línea)

# %%
# Crear algunos datos
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Representar los datos y crear una linea en el gráfico
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %% [markdown]
# ### Scatter (diagrama de dispersión)

# %%
# Usamos los mismos datos para hacer un diagrama de dispersión (scatter)
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Otro diagrama de dispersión
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %% [markdown]
# ### Bar (gráfico de barras)
#
# * Horizontal
# * Vertical

# %%
# Crear un gráfico desde un diccionario
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),
       nut_butter_prices.values())
ax.set(title="Nut Butter Store",
       ylabel="Precio (€)")
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(nut_butter_prices.keys(), nut_butter_prices.values());

# %% [markdown]
# ### Histogram (hist)

# %%
x = np.random.randn(1000) # distribución normal
fig, ax = plt.subplots()
ax.hist(x);

# %%
x = np.random.random(1000) # distribución aleatoria
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Subplots
#
# * Múltiples gráficos en una sola figura

# %%
# Opción 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10,5))
# Gráfico para cada eje
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Opción 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))
# Gráfico para cada eje
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));
